# %% [markdown]
# # ITMAL Demo
#
# ## Keras setup and train on MNIST data

# %%
import numpy as np
from libitmal import dataloaders 

X, y = dataloaders.MNIST_GetDataSet()

X = X.reshape(70000, 784)
#X_norm = X*np.float32(1)  # NOTE: ups, remembered convert to float but forgot scale 
X_norm = X/np.float32(255) # NOTE: remembered convert to float and scale 

print(f"X_norm.shape={X_norm.shape}")
print(f"  type(X_norm[0][0])={type(X_norm[0][0])}")
print(f"  X_norm.dtype={X_norm.dtype}")
print(f"  np.max(X_norm)={np.max(X_norm)}")print(f"  np.min(X_norm)={np.min(X_norm)}")

from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3, random_state=42)

y_train_cat = to_categorical(y_train)
y_test_cat  = to_categorical(y_test)
# Out:
# X_norm.shape=(70000, 784)
#   type(X_norm[0][0])=<class 'numpy.float32'>
#   X_norm.dtype=float32
#   np.max(X_norm)=1.0
#   np.min(X_norm)=0.0

# %%
from time import time

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD, Nadam
#from tensorflow.keras.layers.normalization import BatchNormalization
from tensorflow.keras.backend import batch_normalization

def AddLayer(model, units, add_normalization=False, dropout_rate=-1):
    model.add(Dense(units=units, 
                activation="elu", 
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     
    if add_normalization:
        model.add(BatchNormalization())
    if dropout_rate>=0:
        model.add(Dropout(rate=dropout_rate))


model = Sequential()
#model.add(BatchNormalization())
model.add(Dense(input_dim=(784), units=20, 
                activation="elu", 
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     
#model.add(BatchNormalization())
#model.add(Dropout(rate=DROPOUT_RATE))

AddLayer(model, 50)
AddLayer(model, 70)
AddLayer(model, 100)
AddLayer(model, 70)
AddLayer(model, 50)
AddLayer(model, 20)

model.add(Dense(units=10, 
                activation="softmax",
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     

def ModelCompile(model):
    #optimizer = Adam (learning_rate=0.1) # NOTE: will fail miserable for learning_rate=0.1
    #optimizer = Adam (learning_rate=0.01) 
    #optimizer = Nadam(learning_rate=0.002) # NOTE: Nadam=Nesterov Adam optimizer.
    optimizer = SGD  (learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
          
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                   metrics=['categorical_crossentropy',
                            'categorical_accuracy',
                            'mean_squared_error',
                            'mean_absolute_error'])
    try:
        model.summary()
    except:
        print("WARNING: model.summary() failed, cannot print models with BatchNormalization() layers before fit")
    

def PrintScore(model, X_test, y_test_cat, t):
    #print(history.history)
    score = model.evaluate(X_test, y_test_cat, verbose=0)
    print(f"Training time: {t:0.1f} sec")
    print(f"Test loss:     {score[0]}") # loss is score 0 by definition?
    print(f"Test accuracy: {score[2]}")
    #print(f"All scores in history: {score}")
    
# Train
VERBOSE     = 1
EPOCHS      = 20
DROPOUT_RATE= 0.1

ModelCompile(model)

start = time()
history = model.fit(X_train, y_train_cat, 
                    validation_data=(X_test, y_test_cat), 
                    epochs=EPOCHS, 
                    verbose=VERBOSE)
t = time()-start

print("")
PrintScore(model, X_test, y_test_cat, t)
print("\nOK")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                15700
#
#  dense_1 (Dense)             (None, 50)                1050
#
#  dense_2 (Dense)             (None, 70)                3570
#
#  dense_3 (Dense)             (None, 100)               7100
#
#  dense_4 (Dense)             (None, 70)                7070
#
#  dense_5 (Dense)             (None, 50)                3550
#
#  dense_6 (Dense)             (None, 20)                1020
#
#  dense_7 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 39,270
# Trainable params: 39,270
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-25 13:55:24.965323: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: .:/opt/cuda-11.2/lib64:/opt/opencv/opencv4-4.5.1/lib:/opt/pylon5/lib64
# 2022-03-25 13:55:24.965358: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-25 13:55:24.965385: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (leno): /proc/driver/nvidia/version does not exist
# 2022-03-25 13:55:24.965688: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-25 13:55:25.088427: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 153664000 exceeds 10% of free system memory.
# Epoch 1/20
# 1532/1532 [==============================] - 5s 3ms/step - loss: 0.3013 - categorical_crossentropy: 0.3013 - categorical_accuracy: 0.9098 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0263 - val_loss: 0.1938 - val_categorical_crossentropy: 0.1938 - val_categorical_accuracy: 0.9429 - val_mean_squared_error: 0.0086 - val_mean_absolute_error: 0.0168
# Epoch 2/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.1624 - categorical_crossentropy: 0.1624 - categorical_accuracy: 0.9510 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0144 - val_loss: 0.2090 - val_categorical_crossentropy: 0.2090 - val_categorical_accuracy: 0.9394 - val_mean_squared_error: 0.0093 - val_mean_absolute_error: 0.0160
# Epoch 3/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.1312 - categorical_crossentropy: 0.1312 - categorical_accuracy: 0.9597 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0117 - val_loss: 0.1576 - val_categorical_crossentropy: 0.1576 - val_categorical_accuracy: 0.9547 - val_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0124
# Epoch 4/20
# 1532/1532 [==============================] - 5s 3ms/step - loss: 0.1095 - categorical_crossentropy: 0.1095 - categorical_accuracy: 0.9660 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0099 - val_loss: 0.1272 - val_categorical_crossentropy: 0.1272 - val_categorical_accuracy: 0.9628 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0102
# Epoch 5/20
# 1532/1532 [==============================] - 5s 3ms/step - loss: 0.0972 - categorical_crossentropy: 0.0972 - categorical_accuracy: 0.9701 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0088 - val_loss: 0.1408 - val_categorical_crossentropy: 0.1408 - val_categorical_accuracy: 0.9600 - val_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0109
# Epoch 6/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.0876 - categorical_crossentropy: 0.0876 - categorical_accuracy: 0.9733 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0079 - val_loss: 0.1391 - val_categorical_crossentropy: 0.1391 - val_categorical_accuracy: 0.9621 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0098
# Epoch 7/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.0814 - categorical_crossentropy: 0.0814 - categorical_accuracy: 0.9740 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0075 - val_loss: 0.1334 - val_categorical_crossentropy: 0.1334 - val_categorical_accuracy: 0.9626 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0102
# Epoch 8/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.0725 - categorical_crossentropy: 0.0725 - categorical_accuracy: 0.9771 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0067 - val_loss: 0.1252 - val_categorical_crossentropy: 0.1252 - val_categorical_accuracy: 0.9632 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0093
# Epoch 9/20
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0685 - categorical_crossentropy: 0.0685 - categorical_accuracy: 0.9773 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0064 - val_loss: 0.1277 - val_categorical_crossentropy: 0.1277 - val_categorical_accuracy: 0.9642 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0094
# Epoch 10/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.0643 - categorical_crossentropy: 0.0643 - categorical_accuracy: 0.9794 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0060 - val_loss: 0.1185 - val_categorical_crossentropy: 0.1185 - val_categorical_accuracy: 0.9668 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0084
# Epoch 11/20
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0615 - categorical_crossentropy: 0.0615 - categorical_accuracy: 0.9800 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0057 - val_loss: 0.1501 - val_categorical_crossentropy: 0.1501 - val_categorical_accuracy: 0.9608 - val_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0099
# Epoch 12/20
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0575 - categorical_crossentropy: 0.0575 - categorical_accuracy: 0.9814 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0054 - val_loss: 0.1275 - val_categorical_crossentropy: 0.1275 - val_categorical_accuracy: 0.9670 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0084
# Epoch 13/20
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0519 - categorical_crossentropy: 0.0519 - categorical_accuracy: 0.9838 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0049 - val_loss: 0.1453 - val_categorical_crossentropy: 0.1453 - val_categorical_accuracy: 0.9629 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0090
# Epoch 14/20
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0532 - categorical_crossentropy: 0.0532 - categorical_accuracy: 0.9820 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0050 - val_loss: 0.1415 - val_categorical_crossentropy: 0.1415 - val_categorical_accuracy: 0.9649 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0084
# Epoch 15/20
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0483 - categorical_crossentropy: 0.0483 - categorical_accuracy: 0.9842 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0046 - val_loss: 0.1488 - val_categorical_crossentropy: 0.1488 - val_categorical_accuracy: 0.9661 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0081
# Epoch 16/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.0448 - categorical_crossentropy: 0.0448 - categorical_accuracy: 0.9856 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0043 - val_loss: 0.1460 - val_categorical_crossentropy: 0.1460 - val_categorical_accuracy: 0.9650 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0081
# Epoch 17/20
# 1532/1532 [==============================] - 4s 2ms/step - loss: 0.0424 - categorical_crossentropy: 0.0424 - categorical_accuracy: 0.9858 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0040 - val_loss: 0.1484 - val_categorical_crossentropy: 0.1484 - val_categorical_accuracy: 0.9622 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0087
# Epoch 18/20
# 1532/1532 [==============================] - 4s 3ms/step - loss: 0.0461 - categorical_crossentropy: 0.0461 - categorical_accuracy: 0.9848 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0043 - val_loss: 0.1463 - val_categorical_crossentropy: 0.1463 - val_categorical_accuracy: 0.9647 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0083
# Epoch 19/20
# 1532/1532 [==============================] - 4s 3ms/step - loss: 0.0411 - categorical_crossentropy: 0.0411 - categorical_accuracy: 0.9861 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0039 - val_loss: 0.1532 - val_categorical_crossentropy: 0.1532 - val_categorical_accuracy: 0.9639 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0083
# Epoch 20/20
# 1532/1532 [==============================] - 4s 3ms/step - loss: 0.0425 - categorical_crossentropy: 0.0425 - categorical_accuracy: 0.9864 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0040 - val_loss: 0.1458 - val_categorical_crossentropy: 0.1458 - val_categorical_accuracy: 0.9672 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0075
#
# Training time: 76.0 sec
# Test loss:     0.14582985639572144
# Test accuracy: 0.9672380685806274
#
# OK

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

def MakePlots(history):
    N=3
    FX=60
    FY=4
    A=0.4
    S=4

    # Plot loss
    plt.figure(figsize=(FX, FY))
    ax = plt.subplot(1, N, 1)
    plt.plot(history.history["loss"]    , "b--x", markerfacecolor=(0, 0, 1, A), markersize=S)
    plt.plot(history.history["val_loss"], "g-s" , markerfacecolor=(0, 1, 0, A), markersize=S)
    plt.legend(loc="best", labels=("loss(train)","loss(val)"))
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.xlim((0, EPOCHS-1))
    plt.title("Loss-vs-epoch plot")
    plt.show()

    # Plot all metrics + loss
    plt.figure(figsize=(FX, FY))
    ax = plt.subplot(1, N, 2)
    plt.plot(history.history["mean_squared_error"],      "r:x", markerfacecolor=(1, 0, 0, A), markersize=S)
    plt.plot(history.history["val_mean_squared_error"],  "r-x", markerfacecolor=(1, 0, 0, A), markersize=S)
    plt.plot(history.history["mean_absolute_error"],     "b:o", markerfacecolor=(0, 0, 1, A), markersize=S)
    plt.plot(history.history["val_mean_absolute_error"], "b-o", markerfacecolor=(0, 0, 1, A), markersize=S)
    plt.xlabel("epoch")
    plt.ylabel("error")
    plt.xlim((0, EPOCHS-1))
    plt.legend(loc="best", labels=("mean_squared_error(train)",  "mean_squared_error(val)", 
                                   "mean_absolute_error(train)", "mean_absolute_error(val)"))
    plt.title("Error-vs-epoch plot")
    plt.show()

    # Plot accuracy
    plt.figure(figsize=(FX, FY))
    ax = plt.subplot(1, N, 3)
    plt.plot(history.history["categorical_accuracy"],     "m-x", markerfacecolor=(1, 0, 1, A), markersize=S)
    plt.plot(history.history["val_categorical_accuracy"], "m:x", markerfacecolor=(1, 0, 1, A), markersize=S)
    ax.set_ylim([0,1])
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.xlim((0, EPOCHS-1))
    plt.legend(loc="lower right", labels=("accuracy,train","accuracy,val"))
    plt.title("Accuracy-vs-epoch plot")
    plt.show()

MakePlots(history)
print("\nOK")
# Out:
# OK
