# %% [markdown]
# # SWMAL Exercise
#
#
# ##  Artificial Neural Networks as Universal Approximators
#
# In this task, we will explore the approximating capabilities of a basic Artificial Neural Network (ANN) featuring a solitary hidden layer comprising two neurons. The activation function employed in these neurons is the hyperbolic tangent (tanh), while the input and output layers utilize the identity activation function. When a neuron employs the tanh activation function, it can alter its direction once. By employing two neurons together, they can effectively approximate a non-monotonic function that exhibits an ascent followed by a descent, a pattern characterizing a simple function with a single peak.
#
# The exercise provides the data generation function, and a plot illustrating the generated data is presented below.

# %%
import matplotlib.pyplot as plt
import numpy as np

def GenerateSimpleData():
    X = np.linspace(-10, 10, 100)
    y = 2*np.tanh(2*X - 12) - 3*np.tanh(2*X - 4)  
    y = 2*np.tanh(2*X + 2)  - 3*np.tanh(2*X - 4)   
    X = X.reshape(-1, 1) # Scikit-algorithms needs matrix in (:,1)-format
    return X,y

X, y_true = GenerateSimpleData()
plt.plot(X, y_true, "r-.")
plt.legend(["y_true"])
plt.xlabel("X")
plt.ylabel("y")
plt.title("ANN, Groundtruth data simple")
           
print("OK")
# Out:
# OK

# %% [markdown]
# #### Qa) Fitting the model using the data generator
#
# We employ the MLPRegressor for model fitting. The activation function is configured as tanh, and the hidden layers parameter is set to [2], signifying a single layer with two neurons.

# %%
# Create MLP and fit model, just run..
from sklearn.neural_network import MLPRegressor

mlp = MLPRegressor(activation = 'tanh',      # activation function 
                   hidden_layer_sizes = [2], # layes and neurons in layers: one hidden layer with two neurons
                   alpha = 1e-5,             # regularization parameter
                   solver = 'lbfgs',         # quasi-Newton solver
                   max_iter=10000,
                   verbose = True)

mlp.fit(X, y_true)
y_pred = mlp.predict(X)

print("OK")
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28249D+00    |proj g|=  1.49130D+00
#
# At iterate    1    f=  1.81627D+00    |proj g|=  5.40720D-01
#
# At iterate    2    f=  1.52166D+00    |proj g|=  2.55579D-01
#
# At iterate    3    f=  1.41916D+00    |proj g|=  2.35694D-01
#
# At iterate    4    f=  1.14826D+00    |proj g|=  3.36004D-01
#
# At iterate    5    f=  8.40221D-01    |proj g|=  5.90845D-01
#
# At iterate    6    f=  6.17570D-01    |proj g|=  4.11746D-01
#
# At iterate    7    f=  3.97095D-01    |proj g|=  4.44630D-01
#
# At iterate    8    f=  2.34606D-01    |proj g|=  1.97138D-01
#
# At iterate    9    f=  1.23392D-01    |proj g|=  1.24679D-01
#
# At iterate   10    f=  6.42804D-02    |proj g|=  8.45892D-02
#
# At iterate   11    f=  2.57285D-02    |proj g|=  1.01472D-01
#
# At iterate   12    f=  1.25829D-02    |proj g|=  4.72128D-02
#
# At iterate   13    f=  1.05873D-02    |proj g|=  1.33459D-02
#
# At iterate   14    f=  1.02536D-02    |proj g|=  5.73048D-03
#
# At iterate   15    f=  1.00918D-02    |proj g|=  5.69870D-03
#
# At iterate   16    f=  8.97686D-03    |proj g|=  1.15100D-02
#
# At iterate   17    f=  6.99832D-03    |proj g|=  1.75421D-02
#
# At iterate   18    f=  5.48402D-03    |proj g|=  2.64309D-02
#
# At iterate   19    f=  3.40878D-03    |proj g|=  4.55315D-02
#
# At iterate   20    f=  1.94257D-03    |proj g|=  1.27480D-02
#
# At iterate   21    f=  1.14518D-03    |proj g|=  1.03762D-02
#
# At iterate   22    f=  1.05961D-03    |proj g|=  2.08540D-03
#
# At iterate   23    f=  1.04857D-03    |proj g|=  2.01305D-03
#
# At iterate   24    f=  1.01465D-03    |proj g|=  1.75638D-03
#
# At iterate   25    f=  8.61068D-04    |proj g|=  5.42188D-03
#
# At iterate   26    f=  5.67903D-04    |proj g|=  8.60493D-03
#
# At iterate   27    f=  3.79849D-04    |proj g|=  1.78822D-02
#
# At iterate   28    f=  1.13227D-04    |proj g|=  8.43980D-03
#
# At iterate   29    f=  1.23076D-05    |proj g|=  2.12733D-03
#
# At iterate   30    f=  1.53587D-06    |proj g|=  5.61979D-04
#
# At iterate   31    f=  1.10079D-06    |proj g|=  1.27506D-04
# OK
#  This problem is unconstrained.
# At iterate   32    f=  1.05336D-06    |proj g|=  5.14315D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     32     35      1     0     0   5.143D-05   1.053D-06
#   F =   1.0533550088606687E-006
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
plt.plot(X, y_true, "r-")
plt.plot(X, y_pred, "b-.")
plt.legend(["y_true", "y_pred"])
plt.xlabel("X")
plt.ylabel("y")
plt.title("ANN, Groundtruth data simple")


print("Weights and bias:")
print("Weight 1: " , mlp.coefs_[0])
print("Bias 1:   " , mlp.intercepts_[0])
print("Weight 2: " , mlp.coefs_[1])
print("Bias 2:   " , mlp.intercepts_[1])

print("OK")
# Out:
# Weights and bias:
# Weight 1:  [[ 2.00039751 -1.99969358]]
# Bias 1:    [2.00034573 3.99937666]
# Weight 2:  [[2.000016  ]
#  [3.00003328]]
# Bias 2:    [-5.2918356e-05]
# OK

# %% [markdown]
# #### Qb)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### Qc) Mathematical formula for the network

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
w0_0 = mlp.coefs_[0][0][0]
w0_1 = mlp.coefs_[0][0][1]
w1_0 = mlp.coefs_[1][0][0]
w1_1 = mlp.coefs_[1][1][0]
b0_0 = mlp.intercepts_[0][0]
b0_1 = mlp.intercepts_[0][1]
b1_0 = mlp.intercepts_[1][0]
y_math = w1_0 * np.tanh(w0_0 * X + b0_0) + w1_1 * np.tanh(w0_1 * X + b0_1) + b1_0

print("OK")
# Out:
# OK

# %% [markdown]
# __Qd) Ploting of math function__

# %% [markdown]
# Here is the plot of the mathematical function, the predictions made by the MLP, and the actual values. All three exhibit a striking similarity.

# %%
plt.plot(X, y_true, "y-", linewidth=3.0)
plt.plot(X, y_pred, "b--", linewidth=2.0)
plt.plot(X, y_math, "r-", linewidth=1.0)

plt.legend(["y_true", "y_pred", "y_math"])
plt.xlabel("X")
plt.ylabel("y")

print("OK")
# Out:
# OK

# %% [markdown]
# #### Qe)
#
# Let's examine the two components of the function separately. We'll plot each of them individually and then combine them to obtain the complete function.

# %%
y_math1 = w1_0 * np.tanh(w0_0 * X + b0_1)
y_math2 = w1_1 * np.tanh(w0_1 * X + b0_1)
y_math3 = np.dot(b1_0, X)

plt.plot(X, y_math1)
plt.plot(X, y_math2)
plt.plot(X, y_math3, "k--")
plt.plot(X, y_math)

plt.legend(["y_math1", "y_math2", "y_math3", "y_math"])
plt.show()

# %% [markdown]
# __Similarity to a Monotonic tanh Activation Function:__
#
# - The first part of y_math (0.3 * tanh(2 * X + 0.1)) resembles a scaled and shifted tanh activation function.
# It is monotonic and exhibits S-shaped behavior, similar to a tanh activation function.
#
# - The second part of y_math (-0.3 * tanh(5 * X + 3)) also resembles a scaled and shifted tanh activation function but with different scaling and shifting. It is also monotonic and exhibits S-shaped behavior.
#
#
# __Network's Ability to Approximate the Input Function:__
#
# - The two-neuron network, with the appropriate weights and biases, can approximate a complex function by combining the outputs of these two "tanh-like" activation functions.
#
# - By using different scaling and shifting parameters in the two parts and combining them with appropriate weights and biases, the network can model a more complex and non-linear function. This demonstrates the expressive power of neural networks, even with a small number of neurons.
#
# - In this example, the network is able to approximate the input function by combining these two parts with appropriate weights and biases, showing that even a simple network architecture can approximate complex functions when trained effectively.

# %% [markdown]
# #### Qf) Extending the MLP with more neurons and layers
# The approximation is spot on

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# Function to generate Sinc-like data
def GenerateSincData():
    X = np.linspace(-3, 3, 1000) 
    y = sinc_like_function(X)
    X = X.reshape(-1, 1)
    return X, y

# Creating and fitting MLP model with more neurons and layers
mlp = MLPRegressor(
    activation='tanh',
    hidden_layer_sizes=[2, 2],  # Two hidden layers with 50 neurons each
    alpha=1e-5,
    solver='lbfgs',
    max_iter=10000,
    verbose=True
)
mlp.fit(X, y_true)
y_pred = mlp.predict(X)

# Plotting the true Sinc-like function and the MLP approximation
plt.figure(figsize=(10, 6))
plt.plot(X, y_true, label='True', linewidth=2)
plt.plot(X, y_pred, label='Predicted', linestyle='--', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Approximation of Sinc-like Function')
plt.grid(True)
plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           13     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.89179D+00    |proj g|=  1.84262D+00
#
# At iterate    1    f=  2.04328D+00    |proj g|=  8.60391D-01
#
# At iterate    2    f=  1.45757D+00    |proj g|=  3.82072D-01
#
# At iterate    3    f=  1.22451D+00    |proj g|=  2.83310D-01
#
# At iterate    4    f=  9.49490D-01    |proj g|=  5.60031D-01
#
# At iterate    5    f=  7.83154D-01    |proj g|=  2.31979D-01
#
# At iterate    6    f=  7.54923D-01    |proj g|=  2.65111D-01
#
# At iterate    7    f=  7.48774D-01    |proj g|=  8.60842D-02
#
# At iterate    8    f=  7.34697D-01    |proj g|=  5.97131D-02
#
# At iterate    9    f=  7.22014D-01    |proj g|=  8.30037D-02
#
# At iterate   10    f=  7.02453D-01    |proj g|=  3.77144D-02
#
# At iterate   11    f=  6.92069D-01    |proj g|=  4.02301D-02
#
# At iterate   12    f=  6.86713D-01    |proj g|=  4.81078D-02
#
# At iterate   13    f=  6.84651D-01    |proj g|=  4.27676D-02
#
# At iterate   14    f=  6.82483D-01    |proj g|=  2.58847D-02
#
# At iterate   15    f=  6.81657D-01    |proj g|=  1.34201D-02
#
# At iterate   16    f=  6.81343D-01    |proj g|=  3.53422D-03
#
# At iterate   17    f=  6.81276D-01    |proj g|=  3.28577D-03
#
# At iterate   18    f=  6.81266D-01    |proj g|=  2.05637D-03
#
# At iterate   19    f=  6.81252D-01    |proj g|=  1.07336D-03
#
# At iterate   20    f=  6.81246D-01    |proj g|=  7.04580D-04
#
# At iterate   21    f=  6.81244D-01    |proj g|=  7.01554D-04
#
# At iterate   22    f=  6.81236D-01    |proj g|=  1.58378D-03
#
# At iterate   23    f=  6.81216D-01    |proj g|=  2.39213D-03
#
# At iterate   24    f=  6.81182D-01    |proj g|=  1.04464D-02
#
# At iterate   25    f=  6.81122D-01    |proj g|=  6.84929D-03
#
# At iterate   26    f=  6.81091D-01    |proj g|=  5.73036D-03
#
# At iterate   27    f=  6.81082D-01    |proj g|=  2.19975D-03
#
# At iterate   28    f=  6.81066D-01    |proj g|=  3.31233D-03
#
# At iterate   29    f=  6.81055D-01    |proj g|=  1.42516D-03
#
# At iterate   30    f=  6.81049D-01    |proj g|=  1.64672D-03
#
# At iterate   31    f=  6.81029D-01    |proj g|=  2.00765D-03
#
# At iterate   32    f=  6.81011D-01    |proj g|=  3.97810D-03
#
# At iterate   33    f=  6.80987D-01    |proj g|=  6.87793D-03
#
# At iterate   34    f=  6.80973D-01    |proj g|=  4.08469D-03
#
# At iterate   35    f=  6.80953D-01    |proj g|=  2.07453D-03
#
# At iterate   36    f=  6.80934D-01    |proj g|=  4.56496D-03
#
# At iterate   37    f=  6.80926D-01    |proj g|=  2.00302D-03
#
# At iterate   38    f=  6.80916D-01    |proj g|=  1.92743D-03
#
# At iterate   39    f=  6.80896D-01    |proj g|=  2.76825D-03
#
# At iterate   40    f=  6.80879D-01    |proj g|=  3.72406D-03
#
# At iterate   41    f=  6.80870D-01    |proj g|=  1.12073D-03
#
# At iterate   42    f=  6.80855D-01    |proj g|=  2.24425D-03
#
# At iterate   43    f=  6.80847D-01    |proj g|=  5.58084D-03
#
# At iterate   44    f=  6.80839D-01    |proj g|=  2.32093D-03
#
# At iterate   45    f=  6.80831D-01    |proj g|=  1.45143D-03
#
# At iterate   46    f=  6.80823D-01    |proj g|=  3.29667D-03
#
# At iterate   47    f=  6.80814D-01    |proj g|=  3.39462D-03
#
# At iterate   48    f=  6.80803D-01    |proj g|=  1.89211D-03
#
# At iterate   49    f=  6.80797D-01    |proj g|=  2.74624D-03
#
# At iterate   50    f=  6.80790D-01    |proj g|=  4.59014D-03
#
# At iterate   51    f=  6.80782D-01    |proj g|=  1.05855D-03
#
# At iterate   52    f=  6.80775D-01    |proj g|=  1.86855D-03
#
# At iterate   53    f=  6.80770D-01    |proj g|=  3.53059D-03
#
# At iterate   54    f=  6.80763D-01    |proj g|=  3.29648D-03
#
# At iterate   55    f=  6.80753D-01    |proj g|=  2.14320D-03
#
# At iterate   56    f=  6.80748D-01    |proj g|=  3.77260D-03
#
# At iterate   57    f=  6.80736D-01    |proj g|=  2.06023D-03
#
# At iterate   58    f=  6.80730D-01    |proj g|=  1.11140D-03
#
# At iterate   59    f=  6.80724D-01    |proj g|=  3.05433D-03
#
# At iterate   60    f=  6.80711D-01    |proj g|=  2.63203D-03
#
# At iterate   61    f=  6.80698D-01    |proj g|=  3.08201D-03
#
# At iterate   62    f=  6.80690D-01    |proj g|=  5.40764D-03
#
# At iterate   63    f=  6.80673D-01    |proj g|=  3.25276D-03
#
# At iterate   64    f=  6.80664D-01    |proj g|=  4.27307D-03
#
# At iterate   65    f=  6.80644D-01    |proj g|=  5.28882D-03
#
# At iterate   66    f=  6.80627D-01    |proj g|=  6.89308D-03
#
# At iterate   67    f=  6.80593D-01    |proj g|=  5.39615D-03
#
# At iterate   68    f=  6.80574D-01    |proj g|=  1.12319D-02
#
# At iterate   69    f=  6.80525D-01    |proj g|=  1.51132D-02
#
# At iterate   70    f=  6.80430D-01    |proj g|=  2.43988D-02
#
# At iterate   71    f=  6.80308D-01    |proj g|=  3.57727D-02
#
# At iterate   72    f=  6.80065D-01    |proj g|=  4.96580D-02
#
# At iterate   73    f=  6.79684D-01    |proj g|=  5.20221D-02
#
# At iterate   74    f=  6.78841D-01    |proj g|=  7.95203D-02
#
# At iterate   75    f=  6.74821D-01    |proj g|=  2.35141D-01
#
# At iterate   76    f=  6.72896D-01    |proj g|=  3.55864D-01
#
# At iterate   77    f=  6.72137D-01    |proj g|=  3.99662D-01
#
# At iterate   78    f=  6.69075D-01    |proj g|=  4.40953D-01
#
# At iterate   79    f=  6.60633D-01    |proj g|=  4.67021D-01
#
# At iterate   80    f=  6.14063D-01    |proj g|=  3.50828D-01
#
# At iterate   81    f=  5.79983D-01    |proj g|=  3.53862D-01
#
# At iterate   82    f=  5.62057D-01    |proj g|=  1.99279D-01
#
# At iterate   83    f=  5.24183D-01    |proj g|=  5.39678D-01
#
# At iterate   84    f=  4.93115D-01    |proj g|=  8.25654D-01
#
# At iterate   85    f=  4.38487D-01    |proj g|=  6.34211D-01
#
# At iterate   86    f=  2.48850D-01    |proj g|=  1.63429D+00
#
# At iterate   87    f=  2.21478D-01    |proj g|=  1.74011D+00
#
# At iterate   88    f=  1.45848D-01    |proj g|=  3.14197D-01
#
# At iterate   89    f=  1.11577D-01    |proj g|=  2.73892D-01
#
# At iterate   90    f=  9.87828D-02    |proj g|=  1.53438D-01
#
# At iterate   91    f=  9.13928D-02    |proj g|=  3.12312D-01
#
# At iterate   92    f=  8.52123D-02    |proj g|=  1.06140D-01
#
# At iterate   93    f=  8.01421D-02    |proj g|=  8.31034D-02
#
# At iterate   94    f=  6.53438D-02    |proj g|=  1.68975D-01
#
# At iterate   95    f=  5.85901D-02    |proj g|=  6.60324D-02
#
# At iterate   96    f=  5.64725D-02    |proj g|=  1.01452D-01
#
# At iterate   97    f=  5.54916D-02    |proj g|=  6.76952D-02
#
# At iterate   98    f=  5.48254D-02    |proj g|=  3.26991D-02
#
# At iterate   99    f=  5.43237D-02    |proj g|=  4.41266D-02
#
# At iterate  100    f=  5.40734D-02    |proj g|=  1.89539D-02
#
# At iterate  101    f=  5.40429D-02    |proj g|=  5.02782D-02
#
# At iterate  102    f=  5.40015D-02    |proj g|=  2.95538D-02
#
# At iterate  103    f=  5.39918D-02    |proj g|=  7.80208D-03
#
# At iterate  104    f=  5.39898D-02    |proj g|=  6.39978D-03
#
# At iterate  105    f=  5.39845D-02    |proj g|=  8.03673D-03
#
# At iterate  106    f=  5.39745D-02    |proj g|=  6.39586D-03
#
# At iterate  107    f=  5.39477D-02    |proj g|=  9.29718D-03
#
# At iterate  108    f=  5.38968D-02    |proj g|=  1.97070D-02
#
# At iterate  109    f=  5.38019D-02    |proj g|=  2.77304D-02
#
# At iterate  110    f=  5.36319D-02    |proj g|=  3.34699D-02
#
# At iterate  111    f=  5.35618D-02    |proj g|=  3.82332D-02
#
# At iterate  112    f=  5.32072D-02    |proj g|=  2.74699D-02
#
# At iterate  113    f=  5.31320D-02    |proj g|=  1.50182D-01
#
# At iterate  114    f=  5.26137D-02    |proj g|=  4.66525D-02
#
# At iterate  115    f=  5.20548D-02    |proj g|=  1.11923D-01
#
# At iterate  116    f=  5.16475D-02    |proj g|=  5.72681D-02
#
# At iterate  117    f=  5.12657D-02    |proj g|=  7.15235D-02
#
# At iterate  118    f=  5.11586D-02    |proj g|=  9.72154D-02
#
# At iterate  119    f=  5.08401D-02    |proj g|=  1.04587D-01
#
# At iterate  120    f=  4.98496D-02    |proj g|=  6.78882D-02
#
# At iterate  121    f=  4.84206D-02    |proj g|=  3.65287D-02
#
# At iterate  122    f=  4.76395D-02    |proj g|=  4.88503D-02
#
# At iterate  123    f=  4.61582D-02    |proj g|=  7.24819D-02
#
# At iterate  124    f=  4.56201D-02    |proj g|=  7.12775D-02
#
# At iterate  125    f=  4.55432D-02    |proj g|=  1.55764D-01
#
# At iterate  126    f=  4.45309D-02    |proj g|=  2.44974D-02
#
# At iterate  127    f=  4.40526D-02    |proj g|=  1.47400D-01
#
# At iterate  128    f=  4.32786D-02    |proj g|=  7.43856D-02
#
# At iterate  129    f=  4.28376D-02    |proj g|=  2.42708D-01
#
# At iterate  130    f=  4.15537D-02    |proj g|=  9.75849D-02
#
# At iterate  131    f=  4.10243D-02    |proj g|=  8.99027D-02
#
# At iterate  132    f=  4.06865D-02    |proj g|=  1.55533D-01
#
# At iterate  133    f=  4.02164D-02    |proj g|=  7.30077D-02
#
# At iterate  134    f=  3.97239D-02    |proj g|=  1.38584D-01
#
# At iterate  135    f=  3.94739D-02    |proj g|=  1.15730D-01
#
# At iterate  136    f=  3.88327D-02    |proj g|=  5.79220D-02
#
# At iterate  137    f=  3.77728D-02    |proj g|=  7.07674D-02
#
# At iterate  138    f=  3.73008D-02    |proj g|=  6.68713D-02
#
# At iterate  139    f=  3.70873D-02    |proj g|=  6.14781D-02
#
# At iterate  140    f=  3.68068D-02    |proj g|=  2.83620D-02
#
# At iterate  141    f=  3.53073D-02    |proj g|=  1.12366D-01
#
# At iterate  142    f=  3.49955D-02    |proj g|=  1.23089D-01
#
# At iterate  143    f=  3.39731D-02    |proj g|=  1.35967D-01
#
# At iterate  144    f=  3.38066D-02    |proj g|=  7.08738D-02
#
# At iterate  145    f=  3.29992D-02    |proj g|=  8.83107D-02
#
# At iterate  146    f=  3.21415D-02    |proj g|=  1.27490D-01
#
# At iterate  147    f=  3.16603D-02    |proj g|=  2.06130D-02
#
# At iterate  148    f=  3.10165D-02    |proj g|=  2.82108D-02
#
# At iterate  149    f=  3.04331D-02    |proj g|=  5.84070D-02
#
# At iterate  150    f=  2.98447D-02    |proj g|=  8.62702D-02
#
# At iterate  151    f=  2.95836D-02    |proj g|=  1.87229D-01
#
# At iterate  152    f=  2.87213D-02    |proj g|=  5.87804D-02
#
# At iterate  153    f=  2.81088D-02    |proj g|=  7.57338D-02
#
# At iterate  154    f=  2.73641D-02    |proj g|=  3.75906D-02
#
# At iterate  155    f=  2.71339D-02    |proj g|=  1.40379D-01
#
# At iterate  156    f=  2.67464D-02    |proj g|=  2.85451D-02
#
# At iterate  157    f=  2.60013D-02    |proj g|=  4.09807D-02
#
# At iterate  158    f=  2.51764D-02    |proj g|=  6.33456D-02
#
# At iterate  159    f=  2.38151D-02    |proj g|=  2.29699D-02
#
# At iterate  160    f=  2.32925D-02    |proj g|=  6.95365D-02
#
# At iterate  161    f=  2.29382D-02    |proj g|=  4.49107D-02
#
# At iterate  162    f=  2.27276D-02    |proj g|=  6.11590D-02
#
# At iterate  163    f=  2.25967D-02    |proj g|=  4.41305D-02
#
# At iterate  164    f=  2.25078D-02    |proj g|=  2.21376D-02
#
# At iterate  165    f=  2.23838D-02    |proj g|=  5.89799D-03
#
# At iterate  166    f=  2.23662D-02    |proj g|=  1.57998D-02
#
# At iterate  167    f=  2.23573D-02    |proj g|=  8.34989D-03
#
# At iterate  168    f=  2.23552D-02    |proj g|=  1.77833D-03
#
# At iterate  169    f=  2.23541D-02    |proj g|=  8.36078D-04
#
# At iterate  170    f=  2.23540D-02    |proj g|=  3.46959D-04
#
# At iterate  171    f=  2.23537D-02    |proj g|=  1.07933D-03
#
# At iterate  172    f=  2.23536D-02    |proj g|=  1.50425D-03
#
# At iterate  173    f=  2.23527D-02    |proj g|=  2.80914D-03
#
# At iterate  174    f=  2.23526D-02    |proj g|=  2.75614D-03
#
# At iterate  175    f=  2.23521D-02    |proj g|=  1.03750D-03
#
# At iterate  176    f=  2.23520D-02    |proj g|=  8.01724D-04
#
# At iterate  177    f=  2.23520D-02    |proj g|=  9.12359D-04
#
# At iterate  178    f=  2.23519D-02    |proj g|=  1.64855D-04
#
# At iterate  179    f=  2.23519D-02    |proj g|=  6.15722D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    13    179    231      1     0     0   6.157D-05   2.235D-02
#   F =   2.2351945826557643E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.

# %% [markdown]
# We have found that a simple ANN with just one hidden layer and two neurons can handle basic functions with one peak quite well. But when it comes to more complex stuff like the sinc function, it falls short. To tackle those trickier tasks, well need to beef up the MLPs capabilities, adjusting its structure to handle more complicated functions like sinc. It's all about using the right tool for the job.
